# %%
import keras
from keras import layers

original_dim = 28 * 28
intermediate_dim = 64
latent_dim = 2

inputs = keras.Input(shape=(original_dim,))
h = layers.Dense(intermediate_dim, activation='relu')(inputs)
z_mean = layers.Dense(latent_dim)(h)
z_log_sigma = layers.Dense(latent_dim)(h)

# %%
from keras import backend as K

def sampling(args):
    z_mean, z_log_sigma = args
    epsilon = K.random_normal(shape=(K.shape(z_mean)[0], latent_dim),
                              mean=0., stddev=0.1)
    return z_mean + K.exp(z_log_sigma) * epsilon

z = layers.Lambda(sampling)([z_mean, z_log_sigma])

# %%
# Create encoder
encoder = keras.Model(inputs, [z_mean, z_log_sigma, z], name='encoder')

# Create decoder
latent_inputs = keras.Input(shape=(latent_dim,), name='z_sampling')
x = layers.Dense(intermediate_dim, activation='relu')(latent_inputs)
outputs = layers.Dense(original_dim, activation='sigmoid')(x)
decoder = keras.Model(latent_inputs, outputs, name='decoder')

# instantiate VAE model
outputs = decoder(encoder(inputs)[2])
vae = keras.Model(inputs, outputs, name='vae_mlp')

# %%
reconstruction_loss = keras.losses.binary_crossentropy(inputs, outputs)
reconstruction_loss *= original_dim
kl_loss = 1 + z_log_sigma - K.square(z_mean) - K.exp(z_log_sigma)
kl_loss = K.sum(kl_loss, axis=-1)
kl_loss *= -0.5
vae_loss = K.mean(reconstruction_loss + kl_loss)
vae.add_loss(vae_loss)
vae.compile(optimizer='adam')

# %%
from keras.datasets import mnist
import numpy as np

(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))

vae.fit(x_train, x_train,
        epochs=100,
        batch_size=32,
        validation_data=(x_test, x_test))
# Out:
# Epoch 1/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 186.3678 - val_loss: 168.0045
# Epoch 2/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 165.5256 - val_loss: 163.5553
# Epoch 3/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 162.1771 - val_loss: 161.0779
# Epoch 4/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 159.9537 - val_loss: 159.1648
# Epoch 5/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 158.1630 - val_loss: 157.8200
# Epoch 6/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 156.5884 - val_loss: 155.8637
# Epoch 7/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 155.2719 - val_loss: 154.8228
# Epoch 8/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 154.3045 - val_loss: 154.0047
# Epoch 9/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 153.5995 - val_loss: 153.6474
# Epoch 10/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 153.0143 - val_loss: 153.1404
# Epoch 11/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 152.4951 - val_loss: 152.6518
# Epoch 12/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 152.0483 - val_loss: 151.9905
# Epoch 13/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 151.6308 - val_loss: 151.7581
# Epoch 14/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 151.2408 - val_loss: 151.6096
# Epoch 15/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 150.9158 - val_loss: 151.1994
# Epoch 16/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 150.5925 - val_loss: 150.9752
# Epoch 17/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 150.3241 - val_loss: 150.5706
# Epoch 18/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 150.0582 - val_loss: 150.6206
# Epoch 19/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 149.7926 - val_loss: 150.1922
# Epoch 20/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 149.5556 - val_loss: 150.1550
# Epoch 21/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 149.3414 - val_loss: 149.8998
# Epoch 22/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 149.1047 - val_loss: 149.7626
# Epoch 23/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 148.9145 - val_loss: 149.8696
# Epoch 24/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 148.7545 - val_loss: 149.3640
# Epoch 25/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 148.5591 - val_loss: 149.1053
# Epoch 26/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 148.3997 - val_loss: 149.3779
# Epoch 27/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 148.2428 - val_loss: 148.9076
# Epoch 28/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 148.0866 - val_loss: 148.9084
# Epoch 29/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 147.9223 - val_loss: 148.9045
# Epoch 30/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 147.7930 - val_loss: 148.7947
# Epoch 31/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 147.6496 - val_loss: 148.4848
# Epoch 32/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 147.5267 - val_loss: 148.1969
# Epoch 33/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 147.4236 - val_loss: 148.3931
# Epoch 34/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 147.3064 - val_loss: 148.2269
# Epoch 35/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 147.1995 - val_loss: 148.0787
# Epoch 36/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 147.1080 - val_loss: 148.2795
# Epoch 37/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 147.0186 - val_loss: 148.1245
# Epoch 38/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 146.8907 - val_loss: 147.9576
# Epoch 39/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 146.7993 - val_loss: 147.9137
# Epoch 40/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 146.7179 - val_loss: 147.7428
# Epoch 41/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 146.6070 - val_loss: 147.7772
# Epoch 42/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 146.5418 - val_loss: 147.6532
# Epoch 43/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 146.4441 - val_loss: 147.9993
# Epoch 44/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 146.3580 - val_loss: 147.5855
# Epoch 45/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 146.3013 - val_loss: 147.4750
# Epoch 46/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 146.2139 - val_loss: 147.6472
# Epoch 47/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 146.1434 - val_loss: 147.5715
# Epoch 48/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 146.0819 - val_loss: 147.4417
# Epoch 49/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 146.0087 - val_loss: 147.5348
# Epoch 50/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 145.9519 - val_loss: 147.1742
# Epoch 51/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 145.8547 - val_loss: 147.1555
# Epoch 52/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 145.8021 - val_loss: 147.2824
# Epoch 53/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 145.7419 - val_loss: 147.1273
# Epoch 54/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 145.6886 - val_loss: 147.2746
# Epoch 55/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 145.6663 - val_loss: 147.0843
# Epoch 56/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 145.5426 - val_loss: 146.9091
# Epoch 57/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 145.4862 - val_loss: 146.9926
# Epoch 58/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 145.4304 - val_loss: 147.1034
# Epoch 59/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 145.3794 - val_loss: 147.0522
# Epoch 60/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 145.3270 - val_loss: 146.9396
# Epoch 61/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 145.2839 - val_loss: 146.9688
# Epoch 62/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 145.2029 - val_loss: 146.7296
# Epoch 63/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 145.1432 - val_loss: 146.8937
# Epoch 64/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 145.1257 - val_loss: 146.9404
# Epoch 65/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 145.0454 - val_loss: 146.9431
# Epoch 66/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 145.0362 - val_loss: 146.5625
# Epoch 67/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 144.9572 - val_loss: 146.6629
# Epoch 68/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 144.9064 - val_loss: 146.5897
# Epoch 69/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 144.8852 - val_loss: 146.7415
# Epoch 70/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 144.7884 - val_loss: 146.5893
# Epoch 71/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 144.7572 - val_loss: 146.5623
# Epoch 72/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 144.7072 - val_loss: 146.7093
# Epoch 73/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 144.7146 - val_loss: 146.5786
# Epoch 74/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 144.6582 - val_loss: 146.5090
# Epoch 75/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 144.5763 - val_loss: 146.3881
# Epoch 76/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 144.5620 - val_loss: 146.4363
# Epoch 77/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 144.5095 - val_loss: 146.2758
# Epoch 78/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 144.4690 - val_loss: 146.4909
# Epoch 79/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 144.4026 - val_loss: 146.4068
# Epoch 80/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 144.4070 - val_loss: 146.4515
# Epoch 81/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 144.3257 - val_loss: 146.3342
# Epoch 82/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 144.2741 - val_loss: 146.3553
# Epoch 83/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 144.3224 - val_loss: 146.5323
# Epoch 84/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 144.2198 - val_loss: 146.5270
# Epoch 85/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 144.2191 - val_loss: 146.1530
# Epoch 86/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 144.1790 - val_loss: 146.4381
# Epoch 87/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 144.1419 - val_loss: 146.0247
# Epoch 88/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 144.0643 - val_loss: 146.2187
# Epoch 89/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 144.0744 - val_loss: 146.1873
# Epoch 90/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 144.0453 - val_loss: 146.4712
# Epoch 91/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 144.0036 - val_loss: 146.0913
# Epoch 92/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 143.9747 - val_loss: 145.9759
# Epoch 93/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 143.9182 - val_loss: 146.1415
# Epoch 94/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 143.8962 - val_loss: 146.1775
# Epoch 95/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 143.8573 - val_loss: 145.8859
# Epoch 96/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 143.8230 - val_loss: 146.2597
# Epoch 97/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 143.7928 - val_loss: 146.0909
# Epoch 98/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 143.7706 - val_loss: 146.2034
# Epoch 99/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 143.7373 - val_loss: 146.4991
# Epoch 100/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 143.7188 - val_loss: 146.0617

# %%
batch_size = 32
import matplotlib.pyplot as plt

x_test_encoded = np.array(encoder.predict(x_test, batch_size=batch_size)[0])
print(x_test_encoded.shape)
plt.figure(figsize=(6, 6))
plt.scatter(x_test_encoded[:, 0], x_test_encoded[:, 1], c=y_test)
plt.colorbar()
plt.show()
# Out:
# (10000, 2)

# %%
n = 32  # figure with 15x15 digits
digit_size = 28
figure = np.zeros((digit_size * n, digit_size * n))
# We will sample n points within [-15, 15] standard deviations
grid_x = np.linspace(-2, 2, n)
grid_y = np.linspace(-2, 2, n)

for i, yi in enumerate(grid_x):
    for j, xi in enumerate(grid_y):
        z_sample = np.array([[xi, yi]])
        x_decoded = decoder.predict(z_sample)
        digit = x_decoded[0].reshape(digit_size, digit_size)
        figure[i * digit_size: (i + 1) * digit_size,
               j * digit_size: (j + 1) * digit_size] = digit

plt.figure(figsize=(10, 10))
plt.imshow(figure)
plt.show()

# %%
vae.summary()
# Out:
# Model: "vae_mlp"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 784)]        0
# __________________________________________________________________________________________________
# encoder (Functional)            [(None, 2), (None, 2 50500       input_1[0][0]
# __________________________________________________________________________________________________
# decoder (Functional)            (None, 784)          51152       encoder[0][2]
# __________________________________________________________________________________________________
# tf_op_layer_Minimum (TensorFlow [(None, 784)]        0           decoder[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Maximum (TensorFlow [(None, 784)]        0           tf_op_layer_Minimum[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sub_1 (TensorFlowOp [(None, 784)]        0           tf_op_layer_Maximum[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2 (TensorFlowOp [(None, 784)]        0           tf_op_layer_Maximum[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_1 (TensorFlow [(None, 784)]        0           tf_op_layer_Sub_1[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 64)           50240       input_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Log (TensorFlowOpLa [(None, 784)]        0           tf_op_layer_AddV2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sub (TensorFlowOpLa [(None, 784)]        0           input_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Log_1 (TensorFlowOp [(None, 784)]        0           tf_op_layer_AddV2_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 2)            130         dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 2)            130         dense[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul (TensorFlowOpLa [(None, 784)]        0           input_1[0][0]
#                                                                  tf_op_layer_Log[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_1 (TensorFlowOp [(None, 784)]        0           tf_op_layer_Sub[0][0]
#                                                                  tf_op_layer_Log_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_3 (TensorFlow [(None, 2)]          0           dense_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Square (TensorFlowO [(None, 2)]          0           dense_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_2 (TensorFlow [(None, 784)]        0           tf_op_layer_Mul[0][0]
#                                                                  tf_op_layer_Mul_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sub_2 (TensorFlowOp [(None, 2)]          0           tf_op_layer_AddV2_3[0][0]
#                                                                  tf_op_layer_Square[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Exp (TensorFlowOpLa [(None, 2)]          0           dense_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Neg (TensorFlowOpLa [(None, 784)]        0           tf_op_layer_AddV2_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sub_3 (TensorFlowOp [(None, 2)]          0           tf_op_layer_Sub_2[0][0]
#                                                                  tf_op_layer_Exp[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mean (TensorFlowOpL [(None,)]            0           tf_op_layer_Neg[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sum (TensorFlowOpLa [(None,)]            0           tf_op_layer_Sub_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_2 (TensorFlowOp [(None,)]            0           tf_op_layer_Mean[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_3 (TensorFlowOp [(None,)]            0           tf_op_layer_Sum[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_4 (TensorFlow [(None,)]            0           tf_op_layer_Mul_2[0][0]
#                                                                  tf_op_layer_Mul_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mean_1 (TensorFlowO [()]                 0           tf_op_layer_AddV2_4[0][0]
# __________________________________________________________________________________________________
# add_loss (AddLoss)              ()                   0           tf_op_layer_Mean_1[0][0]
# ==================================================================================================
# Total params: 101,652
# Trainable params: 101,652
# Non-trainable params: 0
# __________________________________________________________________________________________________
